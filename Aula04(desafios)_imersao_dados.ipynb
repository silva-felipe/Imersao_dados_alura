# %% [markdown]
# <a href="https://colab.research.google.com/github/silva-felipe/Imersao_dados_alura/blob/main/Aula04(desafios)_imersao_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set()

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.columns = [coluna.replace('-', '') for coluna in dados.columns]

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# ###Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %% [markdown]
# Uma forma de ver os MOAs! aqui estou verificando os 10 primeiros por categoria.

# %%
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
tipos_mecanismos = []
for tipo in contagem_moa.index:
  tipos_mecanismos.append(tipo.split('_')[-1])

# %%
df_tipo_mecanismos = pd.DataFrame(data=tipos_mecanismos, columns=['tipos']).value_counts()
df_tipo_mecanismos = pd.DataFrame(data=df_tipo_mecanismos,columns=['counts']).reset_index()

# %%
df_tipo_mecanismos.columns = ['tipos','qtd']
df_tipo_mecanismos.head(10)
# Out:
#                tipos  qtd
# 0          inhibitor  112
# 1         antagonist   32
# 2            agonist   28
# 3          activator    5
# 4              agent    3
# 5            blocker    2
# 6        antioxidant    1
# 7          analgesic    1
# 8  anti-inflammatory    1
# 9     antiarrhythmic    1

# %%
plt.figure(figsize=(12,9))
ax = sns.barplot(data=df_tipo_mecanismos.head(10), x='qtd', y='tipos', palette='Set2')
ax.set_title("10 MOA's mais frequentes por categoria\n".upper(), fontsize=18)
ax.set_xlabel("\nQuantidade das categorias de MOA's".upper())
ax.set_ylabel("\ncategorias de MOA's".upper())
plt.show()

# %% [markdown]
# modo diferente de ver os 10 primeiros MOAs, que acaba alterando a ordem.

# %%
moas = pd.DataFrame(data=contagem_moa, columns=['qtd']).reset_index()
moas.columns = ['MOAs','qtd']
moas
# Out:
#                                            MOAs  qtd
# 0                                nfkb_inhibitor  832
# 1                          proteasome_inhibitor  726
# 2                      cyclooxygenase_inhibitor  435
# 3                  dopamine_receptor_antagonist  424
# 4                 serotonin_receptor_antagonist  404
# ..                                          ...  ...
# 201               protein_phosphatase_inhibitor    6
# 202                         autotaxin_inhibitor    6
# 203                                    diuretic    6
# 204                             erbb2_inhibitor    1
# 205  atp-sensitive_potassium_channel_antagonist    1
#
# [206 rows x 2 columns]

# %%
tipos_mecanismos[:10]
# Out:
# ['inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor']

# %%
moas['tipo_acao'] = tipos_mecanismos 
moas.head()
# Out:
#                             MOAs  qtd   tipo_acao
# 0                 nfkb_inhibitor  832   inhibitor
# 1           proteasome_inhibitor  726   inhibitor
# 2       cyclooxygenase_inhibitor  435   inhibitor
# 3   dopamine_receptor_antagonist  424  antagonist
# 4  serotonin_receptor_antagonist  404  antagonist

# %%
moas_mais_freq = moas.groupby('tipo_acao').agg({'qtd':'sum'}).sort_values('qtd', ascending=False).head(10).reset_index()
moas_mais_freq
# Out:
#            tipo_acao   qtd
# 0          inhibitor  9693
# 1         antagonist  3449
# 2            agonist  2330
# 3            blocker   323
# 4              agent   150
# 5          activator   115
# 6              local    80
# 7        antioxidant    73
# 8  anti-inflammatory    73
# 9  immunosuppressant    73

# %%
plt.figure(figsize=(12,9))
ax_2 = sns.barplot(data=moas_mais_freq, x='qtd', y='tipo_acao', palette='Set2')
ax_2.set_title("10 MOA's mais frequentes por categoria\n".upper(), fontsize=18)
ax_2.set_xlabel("\nQuantidade das categorias de MOA's".upper())
ax_2.set_ylabel("\ncategorias de MOA's".upper())
plt.show()

# %% [markdown]
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dados.head(2)
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
#
# [2 rows x 877 columns]

# %%
dados['tratamento'] == 'com_controle'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23809    False
# 23810    False
# 23811     True
# 23812    False
# 23813    False
# Name: tratamento, Length: 23814, dtype: bool

# %%
dados_resultados.head(2)
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
#
# [2 rows x 209 columns]

# %%
dados_combinados['eh_controle'] = (dados['tratamento'] == 'com_controle').astype('int')
dados_combinados.head(2)
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True            0
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False            0
#
# [2 rows x 880 columns]

# %%
dados_combinados.loc[dados_combinados['eh_controle'] == 0, 'eh_controle'] = 'NAO'
dados_combinados.loc[dados_combinados['eh_controle'] != 0, 'eh_controle'] = 'SIM'

# %%
dados_combinados.head(2)
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True          SIM
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False          SIM
#
# [2 rows x 880 columns]

# %% [markdown]
# ###Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['24h'] = (dados['tempo'] == '24').astype('int')
dados_combinados.loc[dados_combinados['24h'] == 0, '24h'] = 'X'
dados_combinados.loc[dados_combinados['24h'] != 0, '24h'] = 'O'

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... n_moa  ativo_moa  eh_controle  24h
# 0  id_000644bb2  com_droga     24   D1  ...     1       True          SIM    O
# 1  id_000779bfc  com_droga     72   D1  ...     0      False          SIM    O
# 2  id_000a6266a  com_droga     48   D1  ...     3       True          SIM    O
# 3  id_0015fd391  com_droga     48   D1  ...     0      False          SIM    O
# 4  id_001626bd3  com_droga     72   D2  ...     1       True          SIM    O
#
# [5 rows x 881 columns]

# %%
dados_combinados['48h'] = (dados['tempo'] == '48').astype('int')
dados_combinados.loc[dados_combinados['48h'] == 0, '48h'] = 'X'
dados_combinados.loc[dados_combinados['48h'] != 0, '48h'] = 'O'

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... ativo_moa  eh_controle  24h  48h
# 0  id_000644bb2  com_droga     24   D1  ...      True          SIM    O    O
# 1  id_000779bfc  com_droga     72   D1  ...     False          SIM    O    O
# 2  id_000a6266a  com_droga     48   D1  ...      True          SIM    O    O
# 3  id_0015fd391  com_droga     48   D1  ...     False          SIM    O    O
# 4  id_001626bd3  com_droga     72   D2  ...      True          SIM    O    O
#
# [5 rows x 882 columns]

# %%
dados_combinados['72h'] = (dados['tempo'] == '72').astype('int')
dados_combinados.loc[dados_combinados['72h'] == 0, '72h'] = 'X'
dados_combinados.loc[dados_combinados['72h'] != 0, '72h'] = 'O'

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle  24h  48h  72h
# 0  id_000644bb2  com_droga     24   D1  ...         SIM    O    O    O
# 1  id_000779bfc  com_droga     72   D1  ...         SIM    O    O    O
# 2  id_000a6266a  com_droga     48   D1  ...         SIM    O    O    O
# 3  id_0015fd391  com_droga     48   D1  ...         SIM    O    O    O
# 4  id_001626bd3  com_droga     72   D2  ...         SIM    O    O    O
#
# [5 rows x 883 columns]

# %% [markdown]
# ###Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ###Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)

# %%
composto_principal = dados_combinados['droga'].value_counts().index[0]
composto_principal
# Out:
# 'cacb2b860'

# %%
droga_mais = dados_combinados.query('droga in @composto_principal')
droga_mais.head()
# Out:
#               id    tratamento  tempo dose  ... eh_controle  24h  48h  72h
# 25  id_0054388ec  com_controle     48   D1  ...         SIM    O    O    O
# 38  id_0079af0fb  com_controle     24   D1  ...         SIM    O    O    O
# 40  id_007bfbb91  com_controle     24   D2  ...         SIM    O    O    O
# 47  id_008a986b7  com_controle     48   D2  ...         SIM    O    O    O
# 63  id_009d8340f  com_controle     24   D2  ...         SIM    O    O    O
#
# [5 rows x 883 columns]

# %%
ax = sns.lmplot(x='g0', y='c0', col= 'tempo', row='dose', data=droga_mais, hue='tempo')
plt.show()

# %%
ax = sns.lmplot(x='g0', y='c0', col= 'tempo', row='tratamento', data=droga_mais)
plt.show()

# %% [markdown]
# ###Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %% [markdown]
# ###Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# >Aprendi com o desafio 01 que a pergunta correta em analise de dados é essencial, pois diferentes perguntas geram resultados diferentes na análise. E delimitar corretamente o que se deseja estudar é essencial.
